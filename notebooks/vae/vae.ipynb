# %%
MODEL_CLS = "vae"
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\M1-PJT_ML

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from anomalyBayes import config, datamodule, trainer, evaluator, utils
import autoencoder

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/creditcard.csv"
origin = pd.read_csv(PATH)

# %%
DROP_COL = ["Time", "Amount"]
df = origin.drop(columns=DROP_COL)

# %%
Y_COL = "Class"

kwargs = dict(
    df=df,
    y_col=Y_COL,
    cfg=cfg.datamodule,
)

dataloaders = datamodule.build(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    **cfg.model.params,
)

model = autoencoder.vae.VariationalAutoEncoder(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 37
# BEST SCORE: 0.0988

# %%
SUPTITLE = f"{MODEL_CLS.upper()} Training History"
SCORE = "MSE"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    suptitle=SUPTITLE,
    score=SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
PERCENTILES = [
    0.950 + 0.005*i
    for i in range(10)
]

kwargs = dict(
    model=model,
    val_anomaly=records["val_anomaly"],
    percentiles=PERCENTILES,
    cfg=cfg.evaluator,
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 8/8 [00:00<00:00, 362.34it/s]

# %%
metrics_sheet
# Out:
#        p  threshold   tp   tn  fp  fn  accuracy  precision    recall        f1
# 0  0.950   0.217720  424  470  22  68  0.908537   0.950673  0.861789  0.904051
# 1  0.955   0.232100  424  473  19  68  0.911585   0.957111  0.861789  0.906952
# 2  0.960   0.248775  422  474  18  70  0.910569   0.959091  0.857724  0.905579
# 3  0.965   0.272388  422  477  15  70  0.913618   0.965675  0.857724  0.908504
# 4  0.970   0.300961  420  483   9  72  0.917683   0.979021  0.853659  0.912052
# 5  0.975   0.341409  418  486   6  74  0.918699   0.985849  0.849594  0.912664
# 6  0.980   0.400108  414  489   3  78  0.917683   0.992806  0.841463  0.910891
# 7  0.985   0.492560  411  491   1  81  0.916667   0.997573  0.835366  0.909292
# 8  0.990   0.663653  408  491   1  84  0.913618   0.997555  0.829268  0.905660
# 9  0.995   1.122185  400  492   0  92  0.906504   1.000000  0.813008  0.896861

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
