# %%
MODEL_CLS = "ae"
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\M1-PJT_ML

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from anomaly import config, datamodule, trainer, evaluator, utils
import autoencoder

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/creditcard.csv"
origin = pd.read_csv(PATH)

# %%
DROP_COL = ["Time", "Amount"]
df = origin.drop(columns=DROP_COL)

# %%
Y_COL = "Class"

kwargs = dict(
    df=df,
    y_col=Y_COL,
    cfg=cfg.datamodule,
)

dataloaders = datamodule.build(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    **cfg.model.params,
)

model = autoencoder.ae.AutoEncoder(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 57
# BEST SCORE: 0.0812

# %%
TITLE = f"{MODEL_CLS.upper()} Training History"
SCORE = "MSE"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    title=TITLE,
    score=SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
PERCENTILES = [
    0.950 + 0.005*i
    for i in range(10)
]

kwargs = dict(
    model=model,
    val_anomaly=records["val_anomaly"],
    percentiles=PERCENTILES,
    cfg=cfg.evaluator,
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 8/8 [00:00<00:00, 304.31it/s]

# %%
metrics_sheet
# Out:
#        p  threshold   tp   tn  fp  fn  accuracy  precision    recall        f1
# 0  0.950   0.215038  434  471  21  58  0.919715   0.953846  0.882114  0.916579
# 1  0.955   0.228115  432  473  19  60  0.919715   0.957871  0.878049  0.916225
# 2  0.960   0.246809  429  475  17  63  0.918699   0.961883  0.871951  0.914712
# 3  0.965   0.269964  425  478  14  67  0.917683   0.968109  0.863821  0.912997
# 4  0.970   0.301916  421  480  12  71  0.915650   0.972286  0.855691  0.910270
# 5  0.975   0.338918  419  483   9  73  0.916667   0.978972  0.851626  0.910870
# 6  0.980   0.390512  416  487   5  76  0.917683   0.988124  0.845528  0.911281
# 7  0.985   0.486628  413  489   3  79  0.916667   0.992788  0.839431  0.909692
# 8  0.990   0.679271  410  490   2  82  0.914634   0.995146  0.833333  0.907080
# 9  0.995   1.133023  400  491   1  92  0.905488   0.997506  0.813008  0.895857

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
