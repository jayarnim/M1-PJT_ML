# %%
MODEL_CLS = "dae"
NOISE = "04"
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M1-PJT_ML

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from anomaly import config, datamodule, trainer, evaluator, utils
import autoencoder

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/creditcard.csv"
origin = pd.read_csv(PATH)

# %%
DROP_COL = ["Time", "Amount"]
df = origin.drop(columns=DROP_COL)

# %%
Y_COL = "Class"

kwargs = dict(
    df=df,
    y_col=Y_COL,
    cfg=cfg.datamodule,
)

dataloaders = datamodule.build(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    noise=float(NOISE)*1e-1,
    **cfg.model.params,
)

model = autoencoder.dae.DenoisedAutoEncoder(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 12
# BEST SCORE: 0.2074

# %%
TITLE = f"{MODEL_CLS.upper()} Training History (Noise: {float(NOISE)*1e-1:.1f})"
SCORE = "MSE"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    title=TITLE,
    score=SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
PERCENTILES = [
    0.950 + 0.005*i
    for i in range(10)
]

kwargs = dict(
    model=model,
    val_anomaly=records["val_anomaly"],
    percentiles=PERCENTILES,
    cfg=cfg.evaluator,
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 8/8 [00:00<00:00, 1454.02it/s]

# %%
metrics_sheet
# Out:
#        p  threshold   tp   tn  fp   fn  accuracy  precision    recall  \
# 0  0.950   0.504168  433  475  17   59  0.922764   0.962222  0.880081
# 1  0.955   0.541606  427  477  15   65  0.918699   0.966063  0.867886
# 2  0.960   0.585698  424  480  12   68  0.918699   0.972477  0.861789
# 3  0.965   0.652807  420  482  10   72  0.916667   0.976744  0.853659
# 4  0.970   0.738401  418  483   9   74  0.915650   0.978923  0.849594
# 5  0.975   0.857083  415  487   5   77  0.916667   0.988095  0.843496
# 6  0.980   1.030568  412  487   5   80  0.913618   0.988010  0.837398
# 7  0.985   1.329379  411  488   4   81  0.913618   0.990361  0.835366
# 8  0.990   1.918836  401  490   2   91  0.905488   0.995037  0.815041
# 9  0.995   2.982473  383  491   1  109  0.888211   0.997396  0.778455
#
#          f1
# 0  0.919321
# 1  0.914347
# 2  0.913793
# 3  0.911063
# 4  0.909684
# 5  0.910088
# 6  0.906491
# 7  0.906284
# 8  0.896089
# 9  0.874429

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}_{NOISE}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}_{NOISE}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}_{NOISE}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
