# %%
MODEL_CLS = "dae"
NOISE = "03"
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M1-PJT_ML

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from anomaly import config, datamodule, trainer, evaluator, utils
import autoencoder

# %%
PATH = f"./config/{MODEL_CLS}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/creditcard.csv"
origin = pd.read_csv(PATH)

# %%
DROP_COL = ["Time", "Amount"]
df = origin.drop(columns=DROP_COL)

# %%
Y_COL = "Class"

kwargs = dict(
    df=df,
    y_col=Y_COL,
    cfg=cfg.datamodule,
)

dataloaders = datamodule.build(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    noise=float(NOISE)*1e-1,
    **cfg.model.params,
)

model = autoencoder.dae.DenoisedAutoEncoder(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 12
# BEST SCORE: 0.1744

# %%
TITLE = f"{MODEL_CLS.upper()} Training History (Noise: {float(NOISE)*1e-1:.1f})"
SCORE = "MSE"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    title=TITLE,
    score=SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
PERCENTILES = [
    0.950 + 0.005*i
    for i in range(10)
]

kwargs = dict(
    model=model,
    val_anomaly=records["val_anomaly"],
    percentiles=PERCENTILES,
    cfg=cfg.evaluator,
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 8/8 [00:00<00:00, 393.68it/s]

# %%
metrics_sheet
# Out:
#        p  threshold   tp   tn  fp   fn  accuracy  precision    recall  \
# 0  0.950   0.405324  430  470  22   62  0.914634   0.951327  0.873984
# 1  0.955   0.436518  425  475  17   67  0.914634   0.961538  0.863821
# 2  0.960   0.468770  422  475  17   70  0.911585   0.961276  0.857724
# 3  0.965   0.517885  418  478  14   74  0.910569   0.967593  0.849594
# 4  0.970   0.572223  416  481  11   76  0.911585   0.974239  0.845528
# 5  0.975   0.661835  412  484   8   80  0.910569   0.980952  0.837398
# 6  0.980   0.779931  411  485   7   81  0.910569   0.983254  0.835366
# 7  0.985   0.979917  409  489   3   83  0.912602   0.992718  0.831301
# 8  0.990   1.311925  408  491   1   84  0.913618   0.997555  0.829268
# 9  0.995   2.092236  391  492   0  101  0.897358   1.000000  0.794715
#
#          f1
# 0  0.911017
# 1  0.910064
# 2  0.906552
# 3  0.904762
# 4  0.905332
# 5  0.903509
# 6  0.903297
# 7  0.904867
# 8  0.905660
# 9  0.885617

# %% [markdown]
# # Save

# %%
PATH = f'./result/score/{MODEL_CLS}_{NOISE}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
result.to_csv(**kwargs)

# %%
PATH = f'./result/metric/{MODEL_CLS}_{NOISE}.csv'

kwargs = dict(
    path_or_buf=PATH,
    index=False,
)
metrics_sheet.to_csv(**kwargs)

# %%
PATH = f'./checkpoints/{MODEL_CLS}_{NOISE}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
